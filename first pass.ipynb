# %%
import numpy as np
import pandas as pd

# %%
money_df = pd.read_csv("census_money_data/elsec13t.txt")
diversity_df = pd.read_csv("nces_diversity_data/elsi.csv")

# %%
diversity_df["Agency ID - NCES Assigned [District] Latest available year"]
# Out:
# 0        3400743
# 1        1800046
# 2        4200091
# 3        5500045
# 4     ="0400380"
# 5     ="0400328"
# 6        1700024
# 7        4280010
# 8        4800095
# 9        4800203
# 10       3900305
# 11       3901480
# 12       1700105
# 13       1904080
# 14       5100033
# ...
# 16984    3901396
# 16985    4846770
# 16986    5310170
# 16987    4033600
# 16988    1743860
# 16989    1743890
# 16990    1802830
# 16991    4800193
# 16992    3502800
# 16993    3028910
# 16994        n/a
# 16995        NaN
# 16996        NaN
# 16997        NaN
# 16998        NaN
# Name: Agency ID - NCES Assigned [District] Latest available year, Length: 16999, dtype: object

# %%
money_df["NCESID"]
# Out:
# 0     0100240
# 1     0100270
# 2     0100300
# 3     0101410
# 4     0100360
# 5     0100420
# 6     0102550
# 7     0100480
# 8     0100510
# 9     0100090
# 10    0100540
# 11    0101860
# 12    0102760
# 13    0102635
# 14    0100600
# ...
# 14447    5605695
# 14448    5605680
# 14449    5605690
# 14450    5604860
# 14451    5601260
# 14452    5605762
# 14453    5605302
# 14454    5605830
# 14455    5602760
# 14456    5604500
# 14457    5604260
# 14458    5605820
# 14459    5606240
# 14460    5604830
# 14461    5606090
# Name: NCESID, Length: 14462, dtype: object

# %%
#join the DFs together on the NCES id number
money_diversity_df = pd.merge(money_df, diversity_df,  left_on = "NCESID", right_on = "Agency ID - NCES Assigned [District] Latest available year")

# %%
list(money_diversity_df.columns.values)
# Out:
# ['IDCENSUS',
#  'NAME',
#  'CONUM',
#  'CSA',
#  'CBSA',
#  'NCESID',
#  'ENROLL',
#  'TOTALREV',
#  'TFEDREV',
#  'FEDRCOMP',
#  'FEDRSPEC',
#  'FEDRNUTR',
#  'FEDROTHR',
#  'TSTREV',
#  'STRFORM',
#  'STRSPEC',
#  'STRTRANS',
#  'STROTHR',
#  'TLOCREV',
#  'LOCRTAX',
#  'LOCRPROP',
#  'LOCRPAR',
#  'LOCRCICO',
#  'LOCROSCH',
#  'LOCRCHAR',
#  'LOCROTHR',
#  'TOTALEXP',
#  'TCURSPND',
#  'TSALWAGE',
#  'TEMPBENE',
#  'TCURINST',
#  'TCURISAL',
#  'TCURIBEN',
#  'TCURSSVC',
#  'TCURSPUP',
#  'TCURSSTA',
#  'TCURSGEN',
#  'TCURSSCH',
#  'TCURSOTH',
#  'TCURONON',
#  'TCAPOUT',
#  'TPAYOTH',
#  'TINTRST',
#  'DEBTOUT',
#  'LONGISSU',
#  'LONGRET',
#  'PCTTOTAL',
#  'PCTFTOT',
#  'PCTFCOMP',
#  'PCTSTOT',
#  'PCTSFORM',
#  'PCTLTOT',
#  'PCTLTAXP',
#  'PCTLOTHG',
#  'PCTLCHAR',
#  'PPCSTOT',
#  'PPSALWG',
#  'PPEMPBEN',
#  'PPITOTAL',
#  'PPISALWG',
#  'PPIEMBEN',
#  'PPSTOTAL',
#  'PPSPUPIL',
#  'PPSSTAFF',
#  'PPSGENAD',
#  'PPSSCHAD',
#  'Agency Name',
# ...

# %%
pd.options.display.max_columns = 20

# %%
money_diversity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11260 entries, 0 to 11259
# Columns: 166 entries, IDCENSUS to Other Support Services Staff [District] 2012-13
# dtypes: float64(12), int64(50), object(104)
# memory usage: 14.3+ MB

# %%
#spot check names of schools that were joined
#pd.options.display.max_rows = 11262
#money_diversity_df[["NCESID", "Agency ID - NCES Assigned [District] Latest available year" , "NAME", "Agency Name"]]

# %%
#for cell above with 11262 max rows
#pd.options.display.max_rows = 20

# %%
#PPCSTOT is the per pupil spending for elementary and secondary.  See school13doc.pdf for more info.

#money_diversity_df[["PPCSTOT"]].describe()

# %%
pd.options.display.max_rows = 120
money_diversity_df.dtypes
# Out:
# IDCENSUS                                                          int64
# NAME                                                             object
# CONUM                                                             int64
# CSA                                                              object
# CBSA                                                             object
# NCESID                                                           object
# ENROLL                                                            int64
# TOTALREV                                                          int64
# TFEDREV                                                           int64
# FEDRCOMP                                                          int64
# FEDRSPEC                                                          int64
# FEDRNUTR                                                          int64
# FEDROTHR                                                          int64
# ...

# %%
#get rid of quotes on numbers

money_diversity_df[['American Indian/Alaska Native Students [District] 2013-14',
                    'Asian or Asian/Pacific Islander Students [District] 2013-14',
                    'Hispanic Students [District] 2013-14',
                    'Black Students [District] 2013-14',
                    'White Students [District] 2013-14',
                    'Hawaiian Nat./Pacific Isl. Students [District] 2013-14',
                    'Two or More Races Students [District] 2013-14',
                    'Total Race/Ethnicity [District] 2013-14',
                    'American Indian/Alaska Native Students [Public School] 2013-14',
                    'Asian or Asian/Pacific Islander Students [Public School] 2013-14',
                    'Hispanic Students [Public School] 2013-14',
                    'Black Students [Public School] 2013-14',
                    'White Students [Public School] 2013-14',
                    'Hawaiian Nat./Pacific Isl. Students [Public School] 2013-14',
                    'Two or More Races Students [Public School] 2013-14',
                    'Total Race/Ethnicity [Public School] 2013-14',
                    'Total Students (UG PK-12) [District] 2013-14',
                    'Ungraded Students [District] 2013-14',
                    'Total Students [Public School] 2013-14',
                    'Total Staff [District] 2013-14',
                    'Full-Time Equivalent (FTE) Teachers [District] 2013-14',
                    'Full-Time Equivalent (FTE) Teachers [Public School] 2013-14',
                    'Pupil/Teacher Ratio [District] 2013-14',
                    'Pupil/Teacher Ratio [Public School] 2013-14',
                    'Instructional Aides [District] 2013-14',
                    'Student Support Services Staff [District] 2013-14',
                    'School Administrative Support Staff [District] 2013-14',
                    'Other Support Services Staff [District] 2013-14',
                    'School Administrators [District] 2013-14',
                    'LEA Administrative Support Staff [District] 2013-14',
                    'LEA Administrators [District] 2013-14',
                    'Library Media Support Staff [District] 2013-14',
                    'Librarians/Media Specialists [District] 2013-14',
                    'Total Guidance Counselors [District] 2013-14',
                    'Other Guidance Counselors [District] 2013-14',
                    'Secondary Guidance Counselors [District] 2013-14',
                    'Instructional Coordinators [District] 2013-14',
                    'Elementary Guidance Counselors [District] 2013-14']] = money_diversity_df[['American Indian/Alaska Native Students [District] 2013-14',
                    'Asian or Asian/Pacific Islander Students [District] 2013-14',
                    'Hispanic Students [District] 2013-14',
                    'Black Students [District] 2013-14',
                    'White Students [District] 2013-14',
                    'Hawaiian Nat./Pacific Isl. Students [District] 2013-14',
                    'Two or More Races Students [District] 2013-14',
                    'Total Race/Ethnicity [District] 2013-14',
                    'American Indian/Alaska Native Students [Public School] 2013-14',
                    'Asian or Asian/Pacific Islander Students [Public School] 2013-14',
                    'Hispanic Students [Public School] 2013-14',
                    'Black Students [Public School] 2013-14',
                    'White Students [Public School] 2013-14',
                    'Hawaiian Nat./Pacific Isl. Students [Public School] 2013-14',
                    'Two or More Races Students [Public School] 2013-14',
                    'Total Race/Ethnicity [Public School] 2013-14',
                    'Total Students (UG PK-12) [District] 2013-14',
                    'Ungraded Students [District] 2013-14',
                    'Total Students [Public School] 2013-14',
                    'Total Staff [District] 2013-14',
                    'Full-Time Equivalent (FTE) Teachers [District] 2013-14',
                    'Full-Time Equivalent (FTE) Teachers [Public School] 2013-14',
                    'Pupil/Teacher Ratio [District] 2013-14',
                    'Pupil/Teacher Ratio [Public School] 2013-14',
                    'Instructional Aides [District] 2013-14',
                    'Student Support Services Staff [District] 2013-14',
                    'School Administrative Support Staff [District] 2013-14',
                    'Other Support Services Staff [District] 2013-14',
                    'School Administrators [District] 2013-14',
                    'LEA Administrative Support Staff [District] 2013-14',
                    'LEA Administrators [District] 2013-14',
                    'Library Media Support Staff [District] 2013-14',
                    'Librarians/Media Specialists [District] 2013-14',
                    'Total Guidance Counselors [District] 2013-14',
                    'Other Guidance Counselors [District] 2013-14',
                    'Secondary Guidance Counselors [District] 2013-14',
                    'Instructional Coordinators [District] 2013-14',
                    'Elementary Guidance Counselors [District] 2013-14']].apply(lambda s:s.str.replace('"', "")).apply(lambda s:s.str.replace('=', ""));

# %%
#convert all values for analysis to float
money_diversity_df[[
                    'American Indian/Alaska Native Students [District] 2013-14',
                    'Asian or Asian/Pacific Islander Students [District] 2013-14',
                    'Hispanic Students [District] 2013-14',
                    'Black Students [District] 2013-14',
                    'White Students [District] 2013-14',
                    'Hawaiian Nat./Pacific Isl. Students [District] 2013-14',
                    'Two or More Races Students [District] 2013-14',
                    'Total Race/Ethnicity [District] 2013-14',
                    'American Indian/Alaska Native Students [Public School] 2013-14',
                    'Asian or Asian/Pacific Islander Students [Public School] 2013-14',
                    'Hispanic Students [Public School] 2013-14',
                    'Black Students [Public School] 2013-14',
                    'White Students [Public School] 2013-14',
                    'Hawaiian Nat./Pacific Isl. Students [Public School] 2013-14',
                    'Two or More Races Students [Public School] 2013-14',
                    'Total Race/Ethnicity [Public School] 2013-14',
                    'Total Students (UG PK-12) [District] 2013-14',
                    'Ungraded Students [District] 2013-14',
                    'Total Students [Public School] 2013-14',
                    'Total Staff [District] 2013-14',
                    'Full-Time Equivalent (FTE) Teachers [District] 2013-14',
                    'Full-Time Equivalent (FTE) Teachers [Public School] 2013-14',
                    'Pupil/Teacher Ratio [District] 2013-14',
                    'Pupil/Teacher Ratio [Public School] 2013-14',
                    'Instructional Aides [District] 2013-14',
                    'Student Support Services Staff [District] 2013-14',
                    'School Administrative Support Staff [District] 2013-14',
                    'Other Support Services Staff [District] 2013-14',
                    'School Administrators [District] 2013-14',
                    'LEA Administrative Support Staff [District] 2013-14',
                    'LEA Administrators [District] 2013-14',
                    'Library Media Support Staff [District] 2013-14',
                    'Librarians/Media Specialists [District] 2013-14',
                    'Total Guidance Counselors [District] 2013-14',
                    'Other Guidance Counselors [District] 2013-14',
                    'Secondary Guidance Counselors [District] 2013-14',
                    'Instructional Coordinators [District] 2013-14',
                    'Elementary Guidance Counselors [District] 2013-14']].describe()
# Out:
#        American Indian/Alaska Native Students [District] 2013-14  \
# count                                               11263
# unique                                                450
# top                                                     0
# freq                                                 3002
#
#        Asian or Asian/Pacific Islander Students [District] 2013-14  \
# count                                               11263
# unique                                                832
# top                                                     0
# freq                                                 2584
#
#        Hispanic Students [District] 2013-14 Black Students [District] 2013-14  \
# count                                 11263                             11263
# unique                                 1654                              1583
# top                                       0                                 0
# ...

# %%
#what is in the values?
money_diversity_df[['American Indian/Alaska Native Students [District] 2013-14',
                    'Asian or Asian/Pacific Islander Students [District] 2013-14',
                    'Hispanic Students [District] 2013-14',
                    'Black Students [District] 2013-14',
                    'White Students [District] 2013-14',
                    'Hawaiian Nat./Pacific Isl. Students [District] 2013-14',
                    'Two or More Races Students [District] 2013-14',
                    'Total Race/Ethnicity [District] 2013-14',
                    'American Indian/Alaska Native Students [Public School] 2013-14',
                    'Asian or Asian/Pacific Islander Students [Public School] 2013-14',
                    'Hispanic Students [Public School] 2013-14',
                    'Black Students [Public School] 2013-14',
                    'White Students [Public School] 2013-14',
                    'Hawaiian Nat./Pacific Isl. Students [Public School] 2013-14',
                    'Two or More Races Students [Public School] 2013-14',
                    'Total Race/Ethnicity [Public School] 2013-14',
                    'Total Students (UG PK-12) [District] 2013-14',
                    'Ungraded Students [District] 2013-14',
                    'Total Students [Public School] 2013-14',
                    'Total Staff [District] 2013-14',
                    'Full-Time Equivalent (FTE) Teachers [District] 2013-14',
                    'Full-Time Equivalent (FTE) Teachers [Public School] 2013-14',
                    'Pupil/Teacher Ratio [District] 2013-14',
                    'Pupil/Teacher Ratio [Public School] 2013-14',
                    'Instructional Aides [District] 2013-14',
                    'Student Support Services Staff [District] 2013-14',
                    'School Administrative Support Staff [District] 2013-14',
                    'Other Support Services Staff [District] 2013-14',
                    'School Administrators [District] 2013-14',
                    'LEA Administrative Support Staff [District] 2013-14',
                    'LEA Administrators [District] 2013-14',
                    'Library Media Support Staff [District] 2013-14',
                    'Librarians/Media Specialists [District] 2013-14',
                    'Total Guidance Counselors [District] 2013-14',
                    'Other Guidance Counselors [District] 2013-14',
                    'Secondary Guidance Counselors [District] 2013-14',
                    'Instructional Coordinators [District] 2013-14',
                    'Elementary Guidance Counselors [District] 2013-14']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-205173e342c9> in <module>()
#      37                     'Secondary Guidance Counselors [District] 2013-14',
#      38                     'Instructional Coordinators [District] 2013-14',
# ---> 39                     'Elementary Guidance Counselors [District] 2013-14']].astype(float)
#
# /Users/andrewjtimmons/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, raise_on_error)
#    2212
#    2213         mgr = self._data.astype(
# -> 2214             dtype=dtype, copy=copy, raise_on_error=raise_on_error)
#    2215         return self._constructor(mgr).__finalize__(self)
#    2216
#
# /Users/andrewjtimmons/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, **kwargs)
#    2500
#    2501     def astype(self, dtype, **kwargs):
# ...

# %%
todo
#convert data from oject to float
#get avg/median
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-fc84c635adea> in <module>()
# ----> 1 todo
#       2 #convert data from oject to float
#       3 #get avg/median
#
# NameError: name 'todo' is not defined

# %%
diversity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16979 entries, 0 to 16978
# Data columns (total 54 columns):
# Agency Name                                                         16979 non-null object
# State Name [District] Latest available year                         16975 non-null object
# State Name [District] 2013-14                                       16975 non-null object
# Agency Name [District] 2013-14                                      16975 non-null object
# Agency ID - NCES Assigned [District] Latest available year          16975 non-null object
# County Number [District] 2013-14                                    16975 non-null object
# County Name [District] 2013-14                                      16975 non-null object
# ANSI/FIPS State Code [District] Latest available year               16975 non-null object
# Location Address [District] 2013-14                                 16975 non-null object
# ...
